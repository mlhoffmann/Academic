# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Data2018.xlsx')

# %%
df1=data

# %%
data.index = pd.to_datetime(data['Data'], format='%Y.%m.%d.%H.%M.%S')

# %%
data = data.drop('Data',1)

# %%
data.head()
# Out:
#                      23AI03.PNT  23AI04.PNT  23AI05.PNT  23FC22.MEAS  \
# Data
# 2018-01-01 01:00:00    0.183762    0.164789    0.245109    50.543976
# 2018-01-01 01:30:00    0.190031    0.164789    0.245109    50.575138
# 2018-01-01 02:00:00    0.190031    0.164789    0.245109    50.550999
# 2018-01-01 02:30:00    0.190031    0.164789    0.245109    50.587048
# 2018-01-01 03:00:00    0.190031    0.164789    0.245109    50.500458
#
#                      23FC61.MEAS  23FC80.MEAS  23II01.PNT  23LC19.MEAS  \
# Data
# 2018-01-01 01:00:00   722.154602   999.747437  181.816833    52.821991
# 2018-01-01 01:30:00   713.054321  1000.245544  180.946503    52.816032
# 2018-01-01 02:00:00   718.224854  1000.586304  181.565201    52.808189
# 2018-01-01 02:30:00   726.062012  1000.194885  181.300217    52.778400
# 2018-01-01 03:00:00   714.996338   999.772949  179.135620    52.751953
#
#                      23LC20.MEAS  23PC67.MEAS  ...  23VI04X.PNT  23VI04Y.PNT  \
# ...

# %%
data.describe()
# Out:
#          23AI03.PNT    23AI04.PNT    23AI05.PNT   23FC22.MEAS   23FC61.MEAS  \
# count  17505.000000  17505.000000  17505.000000  17505.000000  17505.000000
# mean       0.204825      0.209982      0.234364     50.439104    713.793880
# std        0.067410      0.086256      0.054455      4.799106    101.673132
# min       -0.012000     -0.012000     -0.012000     -0.860449    131.067108
# 25%        0.174772      0.174961      0.220430     50.890873    694.329895
# 50%        0.208406      0.221062      0.237023     51.049896    726.297791
# 75%        0.242555      0.247802      0.258047     51.928101    760.096619
# max        0.747825      1.212000      0.393469     53.291729    911.687927
#
#         23FC80.MEAS    23II01.PNT   23LC19.MEAS   23LC20.MEAS   23PC67.MEAS  \
# count  17505.000000  17465.000000  17505.000000  17499.000000  17465.000000
# mean     993.810996    176.953462     58.151768     35.279196    258.547471
# ...

# %%
data['23SI01.PNT'].plot(figsize = (20,6))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17521 entries, 0 to 17520
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Data         17521 non-null  datetime64[ns]
#  1   23AI03.PNT   17505 non-null  float64
#  2   23AI04.PNT   17505 non-null  float64
#  3   23AI05.PNT   17505 non-null  float64
#  4   23FC22.MEAS  17505 non-null  float64
#  5   23FC61.MEAS  17505 non-null  float64
#  6   23FC80.MEAS  17505 non-null  float64
#  7   23II01.PNT   17465 non-null  float64
#  8   23LC19.MEAS  17505 non-null  float64
#  9   23LC20.MEAS  17499 non-null  float64
#  10  23PC67.MEAS  17465 non-null  float64
#  11  23PC93.MEAS  17505 non-null  float64
#  12  23PI75.PNT   17465 non-null  float64
#  13  23SI01.PNT   17505 non-null  float64
#  14  23TC57.MEAS  17505 non-null  float64
#  15  23TI53.PNT   17505 non-null  float64
#  16  23TI56.PNT   17505 non-null  float64
#  17  23TI62.PNT   16931 non-null  float64
# ...
